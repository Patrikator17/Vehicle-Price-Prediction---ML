# %%
import pandas as pd
import numpy as np

# %%
###################### Data Preprocessing ############################

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
###################### Model Development ###############################

from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor

# %%
################## Accuracy Check #######################
from sklearn.metrics import r2_score

# %%
################ Warnings Ingore ############

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Import

# %%
data = pd.read_csv('SecondCar.csv')
data.head(2)
# Out:
#                              name  year  km_driven    fuel seller_type  \
# 0  Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1               Tata Nano Lx BSIV  2012      50000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000

# %% [markdown]
# # Data Preprocessing
#
#     1. Data duplicates -- remove
#     2. Missing value > 75% -->> remove column
#     3. Missing value treatment
#     4. Unique Value based removal -->> when unique value == 1 or unique value == len(data)
#     5. Feature engineering -->> variety reduction
#     6. Label Encoding -->> Alphabetical order converted to numbers
#     6.5. Correlation -->>

# %% [markdown]
# # Step 1. Duplicate Data

# %%
print('Before duplicate removal -->>', len(data))
# Out:
# Before duplicate removal -->> 4340

# %%
data = data.drop_duplicates(keep='first')

# %%
print('After duplicate removal -->>', len(data))
# Out:
# After duplicate removal -->> 4340

# %% [markdown]
# # Step 2. Missing value > 75%

# %%
data.isna().sum()
# Out:
# name                0
# year                0
# km_driven           0
# fuel                3
# seller_type         2
# transmission        2
# owner               3
# Rating              4
# ExShowroom Price    0
# selling_price       0
# dtype: int64

# %%
missing_value_df = pd.DataFrame(data.isna().sum(), columns=['missing_value_count'])
missing_value_df
# Out:
#                   missing_value_count
# name                                0
# year                                0
# km_driven                           0
# fuel                                3
# seller_type                         2
# transmission                        2
# owner                               3
# Rating                              4
# ExShowroom Price                    0
# selling_price                       0

# %%
missing_value_df['perc'] = 100*missing_value_df['missing_value_count']/len(data)
missing_value_df
# Out:
#                   missing_value_count      perc
# name                                0  0.000000
# year                                0  0.000000
# km_driven                           0  0.000000
# fuel                                3  0.069124
# seller_type                         2  0.046083
# transmission                        2  0.046083
# owner                               3  0.069124
# Rating                              4  0.092166
# ExShowroom Price                    0  0.000000
# selling_price                       0  0.000000

# %% [markdown]
# ##### filter dataframe based on threshold value

# %%
missing_value_df[missing_value_df['perc']>75]
# Out:
# Empty DataFrame
# Columns: [missing_value_count, perc]
# Index: []

# %% [markdown]
# ##### Store list of columns to be deleted

# %%
columns_to_be_deleted = list(missing_value_df[missing_value_df['perc']>75].index)
columns_to_be_deleted
# Out:
# []

# %% [markdown]
# ##### Delete columns from original data

# %%
data.head(2)
# Out:
#                              name  year  km_driven    fuel seller_type  \
# 0  Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1               Tata Nano Lx BSIV  2012      50000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000

# %%
data.drop(columns=columns_to_be_deleted, inplace=True)
data.head(2)
# Out:
#                              name  year  km_driven    fuel seller_type  \
# 0  Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1               Tata Nano Lx BSIV  2012      50000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000

# %%
# missing_value_df = pd.DataFrame(data.isna().sum(), columns=['missing_value_count'])
# missing_value_df['perc'] = 100*missing_value_df['missing_value_count']/len(data)
# columns_to_be_deleted = list(missing_value_df[missing_value_df['perc']>75].index)
# data.drop(columns=columns_to_be_deleted, inplace=True)

# %% [markdown]
# # Step 3. Missing Value Treatment

# %%
data.isna().sum()
# Out:
# name                0
# year                0
# km_driven           0
# fuel                3
# seller_type         2
# transmission        2
# owner               3
# Rating              4
# ExShowroom Price    0
# selling_price       0
# dtype: int64

# %%
for col in data.columns:
    
    if data[col].dtype == 'object':
#         print(col, '-->>', data[col].dtype, '-->>', data[col].mode()[0])
        data[col].fillna(data[col].mode()[0], inplace = True)
    
    if data[col].dtype != 'object':
#         print('*'*40, col, '-->>', data[col].dtype, '-->>', data[col].median())
        data[col].fillna(data[col].median(), inplace = True)

# %%
data.isna().sum()
# Out:
# name                0
# year                0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# Rating              0
# ExShowroom Price    0
# selling_price       0
# dtype: int64

# %% [markdown]
# # Mean, Mode, Median

# %%
data['fuel'].mode()[0]
# Out:
# 'Diesel'

# %%
data['km_driven'].median()
# Out:
# 60000.0

# %%
data['km_driven'].mean()
# Out:
# 66215.77741935484

# %% [markdown]
# # Unique Value Check

# %%
data['dummy_col'] = 'vinay'
data.head(2)
# Out:
#                              name  year  km_driven    fuel seller_type  \
# 0  Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1               Tata Nano Lx BSIV  2012      50000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
#
#   dummy_col
# 0     vinay
# 1     vinay

# %%
data['dummy_col'].unique()
# Out:
# array(['vinay'], dtype=object)

# %%
for col in data.columns:
    if (data[col].nunique() == 1):
        del data[col]
    elif ((data[col].nunique() == len(data)) & (data[col].dtype == 'object')):
        del data[col]

# %% [markdown]
# # Feature Engineering

# %%
for col in data.columns:
    print(col, '-->>', data[col].nunique(), '-->>', data[col].dtype)
# Out:
# name -->> 1491 -->> object
# year -->> 27 -->> int64
# km_driven -->> 770 -->> int64
# fuel -->> 5 -->> object
# seller_type -->> 3 -->> object
# transmission -->> 2 -->> object
# owner -->> 5 -->> object
# Rating -->> 566 -->> float64
# ExShowroom Price -->> 4331 -->> int64
# selling_price -->> 445 -->> int64

# %% [markdown]
# # Object Column Variety reduction --->> Needs to be done manually

# %%
data['name']
# Out:
# 0                          Tata Indica Vista Aqua 1.4 TDI
# 1                                       Tata Nano Lx BSIV
# 2                        Tata Indica Vista Aqua TDI BSIII
# 3                                Maruti Wagon R LXI Minor
# 4                                       Chevrolet Beat LT
#                               ...
# 4335                              BMW X5 xDrive 30d xLine
# 4336                        BMW 5 Series 520d Luxury Line
# 4337                              BMW X5 xDrive 30d xLine
# 4338             Audi RS7 2015-2019 Sportback Performance
# 4339    Mercedes-Benz S-Class S 350d Connoisseurs Edition
# Name: name, Length: 4340, dtype: object

# %%
data['name'].str.split(" ").str[0]
# Out:
# 0                Tata
# 1                Tata
# 2                Tata
# 3              Maruti
# 4           Chevrolet
#             ...
# 4335              BMW
# 4336              BMW
# 4337              BMW
# 4338             Audi
# 4339    Mercedes-Benz
# Name: name, Length: 4340, dtype: object

# %%
data['company_name'] = data['name'].str.split(" ").str[0]
data.head()
# Out:
#                                name  year  km_driven    fuel seller_type  \
# 0    Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1                 Tata Nano Lx BSIV  2012      50000  Petrol  Individual
# 2  Tata Indica Vista Aqua TDI BSIII  2011      70000  Diesel  Individual
# 3          Maruti Wagon R LXI Minor  2010      80000  Petrol  Individual
# 4                 Chevrolet Beat LT  2010      80000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# 2       Manual   First Owner    11.0            120678         120000
# 3       Manual  Second Owner     9.0            122917         100000
# 4       Manual  Second Owner    10.0            144902         130000
#
#   company_name
# 0         Tata
# 1         Tata
# 2         Tata
# 3       Maruti
# 4    Chevrolet

# %%
name = 'Mahendra*Singh*Dhoni'

# %%
name.split("*")[2]
# Out:
# 'Dhoni'

# %%
data['company_name'].nunique()
# Out:
# 29

# %% [markdown]
# # Numerical Columns -->> Automatic feature engineering

# %%
round(data.describe(),2)
# Out:
#           year  km_driven   Rating  ExShowroom Price  selling_price
# count  4340.00    4340.00  4340.00           4340.00        4340.00
# mean   2013.09   66215.78    11.97         845380.89      504127.31
# std       4.22   46644.10     1.91         884840.54      578548.74
# min    1992.00       1.00     9.00         106001.00       20000.00
# 25%    2011.00   35000.00    10.02         445389.50      208749.75
# 50%    2014.00   60000.00    12.00         596055.00      350000.00
# 75%    2016.00   90000.00    13.76         946243.00      600000.00
# max    2020.00  806599.00    15.00       15538153.00     8900000.00

# %%
range_labels = ['new','medium','high','extreme']
range_limits = [0,35000,60000,90000,1000000]

data['km_bins'] = pd.cut(data['km_driven'], labels=range_labels, bins = range_limits)
data.head()
# Out:
#                                name  year  km_driven    fuel seller_type  \
# 0    Tata Indica Vista Aqua 1.4 TDI  2010     120000  Diesel  Individual
# 1                 Tata Nano Lx BSIV  2012      50000  Petrol  Individual
# 2  Tata Indica Vista Aqua TDI BSIII  2011      70000  Diesel  Individual
# 3          Maruti Wagon R LXI Minor  2010      80000  Petrol  Individual
# 4                 Chevrolet Beat LT  2010      80000  Petrol  Individual
#
#   transmission         owner  Rating  ExShowroom Price  selling_price  \
# 0       Manual  Second Owner     9.0            106001         100000
# 1       Manual  Second Owner     9.0            108556         100000
# 2       Manual   First Owner    11.0            120678         120000
# 3       Manual  Second Owner     9.0            122917         100000
# 4       Manual  Second Owner    10.0            144902         130000
#
#   company_name  km_bins
# 0         Tata  extreme
# 1         Tata   medium
# 2         Tata     high
# 3       Maruti     high
# 4    Chevrolet     high

# %%
# import plotly.express as px

# %%
# fig = px.pie(data, names = 'km_bins', values = 'km_driven')
# fig.show()

# %%
for col in data.columns:
    if data[col].nunique()/len(data) > 0.05:
        if data[col].dtype == 'object':
            print('Please perform manual feature engineering for -->>', col)
        else:
            print('Auto Feature Engineering for -->>', col)
            new_col_name = col + '_bin'
            data[new_col_name] = pd.qcut(data[col],
                                         4, 
                                         labels = ['b1','b2','b3','b4'])
# Out:
# Please perform manual feature engineering for -->> name
# Auto Feature Engineering for -->> km_driven
# Auto Feature Engineering for -->> Rating
# Auto Feature Engineering for -->> ExShowroom Price
# Auto Feature Engineering for -->> selling_price

# %%
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price   company_name  km_bins km_driven_bin Rating_bin  \
# 0            100000           Tata  extreme            b4         b1
# 1            100000           Tata   medium            b2         b1
# 2            120000           Tata     high            b3         b2
# 3            100000         Maruti     high            b3         b1
# 4            130000      Chevrolet     high            b3         b1
# ...             ...            ...      ...           ...        ...
# 4335        4950000            BMW      new            b1         b2
# 4336        4800000            BMW      new            b1         b1
# 4337        4950000            BMW      new            b1         b2
# 4338        8900000           Audi      new            b1         b4
# 4339        8150000  Mercedes-Benz      new            b1         b1
#
#      ExShowroom Price_bin selling_price_bin
# 0                      b1                b1
# 1                      b1                b1
# 2                      b1                b1
# 3                      b1                b1
# 4                      b1                b1
# ...                   ...               ...
# 4335                   b4                b4
# 4336                   b4                b4
# 4337                   b4                b4
# 4338                   b4                b4
# 4339                   b4                b4
#
# [4340 rows x 16 columns]

# %% [markdown]
# # Label Encoding

# %%
data['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
LN = LabelEncoder()

# %%
data['fuel'] = LN.fit_transform(data['fuel'])

# %%
data['fuel'].unique()
# Out:
# array([1, 4, 0, 3, 2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  4340 non-null   object
#  1   year                  4340 non-null   int64
#  2   km_driven             4340 non-null   int64
#  3   fuel                  4340 non-null   int32
#  4   seller_type           4340 non-null   object
#  5   transmission          4340 non-null   object
#  6   owner                 4340 non-null   object
#  7   Rating                4340 non-null   float64
#  8   ExShowroom Price      4340 non-null   int64
#  9   selling_price         4340 non-null   int64
#  10  company_name          4340 non-null   object
#  11  km_bins               4340 non-null   category
#  12  km_driven_bin         4340 non-null   category
#  13  Rating_bin            4340 non-null   category
#  14  ExShowroom Price_bin  4340 non-null   category
#  15  selling_price_bin     4340 non-null   category
# dtypes: category(5), float64(1), int32(1), int64(4), object(5)
# memory usage: 378.3+ KB

# %%
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#       fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0        1  Individual       Manual  Second Owner    9.00            106001
# 1        4  Individual       Manual  Second Owner    9.00            108556
# 2        1  Individual       Manual   First Owner   11.00            120678
# 3        4  Individual       Manual  Second Owner    9.00            122917
# 4        4  Individual       Manual  Second Owner   10.00            144902
# ...    ...         ...          ...           ...     ...               ...
# 4335     1      Dealer    Automatic   First Owner   11.00           9407487
# 4336     1      Dealer    Automatic   First Owner    9.71           9598350
# 4337     1      Dealer    Automatic   First Owner   11.00           9857238
# 4338     4      Dealer    Automatic   First Owner   14.09          14235729
# 4339     1      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price   company_name  km_bins km_driven_bin Rating_bin  \
# 0            100000           Tata  extreme            b4         b1
# 1            100000           Tata   medium            b2         b1
# 2            120000           Tata     high            b3         b2
# 3            100000         Maruti     high            b3         b1
# 4            130000      Chevrolet     high            b3         b1
# ...             ...            ...      ...           ...        ...
# 4335        4950000            BMW      new            b1         b2
# 4336        4800000            BMW      new            b1         b1
# 4337        4950000            BMW      new            b1         b2
# 4338        8900000           Audi      new            b1         b4
# 4339        8150000  Mercedes-Benz      new            b1         b1
#
#      ExShowroom Price_bin selling_price_bin
# 0                      b1                b1
# 1                      b1                b1
# 2                      b1                b1
# 3                      b1                b1
# 4                      b1                b1
# ...                   ...               ...
# 4335                   b4                b4
# 4336                   b4                b4
# 4337                   b4                b4
# 4338                   b4                b4
# 4339                   b4                b4
#
# [4340 rows x 16 columns]

# %%
for col in data.columns:
    if ( data[col].dtype == 'object') | hasattr(data[col], 'cat'):
        data[col] = LN.fit_transform(data[col])

# %%
data
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 0     1228  2010     120000     1            1             1      2    9.00
# 1     1283  2012      50000     4            1             1      2    9.00
# 2     1229  2011      70000     1            1             1      0   11.00
# 3     1041  2010      80000     4            1             1      2    9.00
# 4       56  2010      80000     4            1             1      2   10.00
# ...    ...   ...        ...   ...          ...           ...    ...     ...
# 4335    39  2019      30000     1            0             0      0   11.00
# 4336    30  2019      12999     1            0             0      0    9.71
# 4337    39  2019      30000     1            0             0      0   11.00
# 4338    25  2016      13000     4            0             0      0   14.09
# 4339  1097  2017       6500     1            0             0      0    9.00
#
#       ExShowroom Price  selling_price  company_name  km_bins  km_driven_bin  \
# 0               106001         100000            25        0              3
# 1               108556         100000            25        2              1
# 2               120678         120000            25        1              2
# 3               122917         100000            18        1              2
# 4               144902         130000             3        1              2
# ...                ...            ...           ...      ...            ...
# 4335           9407487        4950000             2        3              0
# 4336           9598350        4800000             2        3              0
# 4337           9857238        4950000             2        3              0
# 4338          14235729        8900000             1        3              0
# 4339          15538153        8150000            19        3              0
#
#       Rating_bin  ExShowroom Price_bin  selling_price_bin
# 0              0                     0                  0
# 1              0                     0                  0
# 2              1                     0                  0
# 3              0                     0                  0
# 4              0                     0                  0
# ...          ...                   ...                ...
# 4335           1                     3                  3
# 4336           0                     3                  3
# 4337           1                     3                  3
# 4338           3                     3                  3
# 4339           0                     3                  3
#
# [4340 rows x 16 columns]

# %% [markdown]
# # Correlation

# %%
corr = 100*data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_5ca6e_row0_col0, #T_5ca6e_row1_col1, #T_5ca6e_row2_col2, #T_5ca6e_row3_col3, #T_5ca6e_row4_col4, #T_5ca6e_row5_col5, #T_5ca6e_row6_col6, #T_5ca6e_row7_col7, #T_5ca6e_row8_col8, #T_5ca6e_row9_col9, #T_5ca6e_row10_col10, #T_5ca6e_row11_col11, #T_5ca6e_row12_col12, #T_5ca6e_row13_col13, #T_5ca6e_row14_col14, #T_5ca6e_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5ca6e_row0_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_5ca6e_row0_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_5ca6e_row0_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_5ca6e_row0_col4, #T_5ca6e_row1_col5, #T_5ca6e_row4_col8, #T_5ca6e_row7_col15 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_5ca6e_row0_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_5ca6e_row0_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_5ca6e_row0_col7, #T_5ca6e_row2_col1, #T_5ca6e_row2_col3, #T_5ca6e_row8_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5ca6e_row0_col8, #T_5ca6e_row0_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_5ca6e_row0_col10, #T_5ca6e_row10_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_5ca6e_row0_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5ca6e_row0_col12 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_5ca6e_row0_col13, #T_5ca6e_row5_col13, #T_5ca6e_row10_col13, #T_5ca6e_row14_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_5ca6e_row0_col14, #T_5ca6e_row10_col14, #T_5ca6e_row12_col10 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5ca6e_row0_col15, #T_5ca6e_row4_col10, #T_5ca6e_row10_col15 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5ca6e_row1_col0, #T_5ca6e_row6_col14, #T_5ca6e_row12_col14 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col2, #T_5ca6e_row2_col4, #T_5ca6e_row4_col0, #T_5ca6e_row5_col1, #T_5ca6e_row6_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col4, #T_5ca6e_row5_col7, #T_5ca6e_row6_col1, #T_5ca6e_row10_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col6, #T_5ca6e_row3_col15, #T_5ca6e_row5_col8, #T_5ca6e_row5_col9, #T_5ca6e_row5_col14, #T_5ca6e_row9_col4, #T_5ca6e_row9_col5, #T_5ca6e_row9_col7, #T_5ca6e_row9_col13, #T_5ca6e_row11_col0, #T_5ca6e_row11_col2, #T_5ca6e_row11_col10, #T_5ca6e_row11_col12, #T_5ca6e_row12_col1, #T_5ca6e_row12_col11, #T_5ca6e_row15_col3, #T_5ca6e_row15_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col7, #T_5ca6e_row1_col13, #T_5ca6e_row2_col7, #T_5ca6e_row4_col7, #T_5ca6e_row8_col4, #T_5ca6e_row8_col13, #T_5ca6e_row15_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_5ca6e_row1_col9, #T_5ca6e_row9_col11 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5ca6e_row1_col10 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5ca6e_row1_col11 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_5ca6e_row1_col12, #T_5ca6e_row4_col1, #T_5ca6e_row11_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5ca6e_row1_col14 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_5ca6e_row1_col15 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_5ca6e_row2_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_5ca6e_row2_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5ca6e_row2_col8 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col11, #T_5ca6e_row14_col0, #T_5ca6e_row14_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col12 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col13, #T_5ca6e_row4_col13, #T_5ca6e_row12_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5ca6e_row2_col15, #T_5ca6e_row14_col13, #T_5ca6e_row15_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5ca6e_row3_col0, #T_5ca6e_row6_col7, #T_5ca6e_row8_col10, #T_5ca6e_row11_col7, #T_5ca6e_row12_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5ca6e_row3_col1, #T_5ca6e_row6_col3, #T_5ca6e_row7_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_5ca6e_row3_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5ca6e_row3_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_5ca6e_row3_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_5ca6e_row3_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_5ca6e_row3_col7, #T_5ca6e_row3_col10, #T_5ca6e_row3_col13, #T_5ca6e_row3_col14, #T_5ca6e_row8_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_5ca6e_row3_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5ca6e_row3_col9, #T_5ca6e_row10_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_5ca6e_row3_col11, #T_5ca6e_row11_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_5ca6e_row3_col12, #T_5ca6e_row5_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5ca6e_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_5ca6e_row4_col3, #T_5ca6e_row5_col3, #T_5ca6e_row5_col4, #T_5ca6e_row10_col8, #T_5ca6e_row10_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5ca6e_row4_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_5ca6e_row4_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5ca6e_row4_col9, #T_5ca6e_row13_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_5ca6e_row4_col11, #T_5ca6e_row12_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_5ca6e_row4_col12 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_5ca6e_row4_col14 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5ca6e_row4_col15, #T_5ca6e_row15_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_5ca6e_row5_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5ca6e_row5_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_5ca6e_row5_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5ca6e_row5_col11 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5ca6e_row5_col12 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_5ca6e_row5_col15, #T_5ca6e_row8_col7, #T_5ca6e_row9_col10, #T_5ca6e_row11_col4, #T_5ca6e_row15_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_5ca6e_row6_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_5ca6e_row6_col2, #T_5ca6e_row14_col11 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_5ca6e_row6_col4, #T_5ca6e_row13_col14 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5ca6e_row6_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5ca6e_row6_col9, #T_5ca6e_row12_col0, #T_5ca6e_row12_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_5ca6e_row6_col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_5ca6e_row6_col11, #T_5ca6e_row7_col9 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5ca6e_row6_col12 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_5ca6e_row6_col13, #T_5ca6e_row11_col13, #T_5ca6e_row12_col15 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_5ca6e_row6_col15, #T_5ca6e_row12_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_5ca6e_row7_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_5ca6e_row7_col1, #T_5ca6e_row15_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_5ca6e_row7_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5ca6e_row7_col4, #T_5ca6e_row7_col10, #T_5ca6e_row13_col10, #T_5ca6e_row14_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_5ca6e_row7_col5, #T_5ca6e_row13_col5, #T_5ca6e_row14_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_5ca6e_row7_col6, #T_5ca6e_row10_col1, #T_5ca6e_row13_col6 {
#   background-color: #9ebeff;

# %%
data.drop(columns=['name','Rating', 'ExShowroom Price'], inplace=True)

# %%
corr = 100*data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_c03c7_row0_col0, #T_c03c7_row1_col1, #T_c03c7_row2_col2, #T_c03c7_row3_col3, #T_c03c7_row4_col4, #T_c03c7_row5_col5, #T_c03c7_row6_col6, #T_c03c7_row7_col7, #T_c03c7_row8_col8, #T_c03c7_row9_col9, #T_c03c7_row10_col10, #T_c03c7_row11_col11, #T_c03c7_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col1, #T_c03c7_row1_col3, #T_c03c7_row4_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col3, #T_c03c7_row5_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c03c7_row0_col5, #T_c03c7_row2_col12, #T_c03c7_row4_col6, #T_c03c7_row4_col11, #T_c03c7_row6_col3, #T_c03c7_row6_col4, #T_c03c7_row6_col10, #T_c03c7_row8_col1, #T_c03c7_row8_col7, #T_c03c7_row8_col9, #T_c03c7_row9_col0, #T_c03c7_row9_col8, #T_c03c7_row12_col2, #T_c03c7_row12_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col6, #T_c03c7_row6_col8 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_c03c7_row0_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c03c7_row0_col9, #T_c03c7_row3_col0, #T_c03c7_row8_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_c03c7_row0_col10, #T_c03c7_row12_col10 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c03c7_row0_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c03c7_row0_col12 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_c03c7_row1_col0, #T_c03c7_row1_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_c03c7_row1_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c03c7_row1_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col8, #T_c03c7_row11_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col9 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col10, #T_c03c7_row3_col10, #T_c03c7_row9_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c03c7_row1_col12, #T_c03c7_row11_col10, #T_c03c7_row12_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c03c7_row2_col0, #T_c03c7_row5_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_c03c7_row2_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_c03c7_row2_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c03c7_row2_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c03c7_row2_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_c03c7_row2_col6, #T_c03c7_row7_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_c03c7_row2_col7, #T_c03c7_row2_col10, #T_c03c7_row2_col11 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c03c7_row2_col8, #T_c03c7_row8_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_c03c7_row2_col9, #T_c03c7_row4_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_c03c7_row3_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c03c7_row3_col2, #T_c03c7_row4_col2, #T_c03c7_row4_col3, #T_c03c7_row7_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c03c7_row3_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_c03c7_row3_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c03c7_row3_col6, #T_c03c7_row10_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c03c7_row3_col7, #T_c03c7_row7_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c03c7_row3_col8, #T_c03c7_row9_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c03c7_row3_col9 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_c03c7_row3_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c03c7_row3_col12, #T_c03c7_row12_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c03c7_row4_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c03c7_row4_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c03c7_row4_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_c03c7_row4_col9 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c03c7_row4_col10, #T_c03c7_row7_col10, #T_c03c7_row11_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c03c7_row4_col12, #T_c03c7_row6_col7, #T_c03c7_row8_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c03c7_row5_col1, #T_c03c7_row11_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c03c7_row5_col3, #T_c03c7_row10_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_c03c7_row5_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c03c7_row5_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c03c7_row5_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c03c7_row5_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_c03c7_row5_col9 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_c03c7_row5_col10, #T_c03c7_row8_col10, #T_c03c7_row9_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c03c7_row5_col11, #T_c03c7_row9_col11 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_c03c7_row5_col12 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c03c7_row6_col0, #T_c03c7_row11_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_c03c7_row6_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c03c7_row6_col2, #T_c03c7_row8_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_c03c7_row6_col5, #T_c03c7_row11_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c03c7_row6_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c03c7_row6_col11 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_c03c7_row6_col12, #T_c03c7_row11_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_c03c7_row7_col0, #T_c03c7_row10_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_c03c7_row7_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c03c7_row7_col3, #T_c03c7_row10_col12 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_c03c7_row7_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c03c7_row7_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_c03c7_row7_col8 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c03c7_row7_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_c03c7_row7_col11, #T_c03c7_row9_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c03c7_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_c03c7_row8_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c03c7_row8_col11 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c03c7_row8_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_c03c7_row9_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_c03c7_row9_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c03c7_row9_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_c03c7_row9_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c03c7_row9_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c03c7_row10_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_c03c7_row10_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c03c7_row10_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c03c7_row10_col4, #T_c03c7_row11_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c03c7_row10_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c03c7_row10_col7, #T_c03c7_row11_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c03c7_row10_col8 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_c03c7_row10_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c03c7_row11_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c03c7_row11_col9 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c03c7_row11_col12 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_c03c7_row12_c

# %% [markdown]
# # Train Test Split

# %%
x = data.drop(columns = 'selling_price')
y = data['selling_price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state = 1234)

# %%
len(x_train)
# Out:
# 3038

# %%
len(y_train)
# Out:
# 3038

# %% [markdown]
# # Model Development
#
#     1. Model Name
#     2. Training
#     3. Exam - Predicted Answers
#     4. Accuracy Check

# %% [markdown]
# ##### Step 1. Model Declaration

# %%
model = LinearRegression()

# %% [markdown]
# ##### Step 2. Model training (fitting)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Step 3. Prediction

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([1438411.5968826 ,  287860.18461718,  294504.20672931, ...,
#        1405617.85825227,  787988.93414171,  652938.87056424])

# %% [markdown]
# ##### Step 4. Accuracy

# %%
accuracy = 100* r2_score(y_test, y_pred)
accuracy
# Out:
# 56.337831680288886

# %% [markdown]
# # Running all model

# %%
models = [LinearRegression(), Lasso(), ElasticNet(), KNeighborsRegressor(),
         DecisionTreeRegressor(), RandomForestRegressor(), AdaBoostRegressor(),
          GradientBoostingRegressor()]

# %%
acc_dic = {}

# %%
for model in models:
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy = 100* r2_score(y_test, y_pred)
    acc_dic[model] = round(accuracy,2)

# %%
acc_dic
# Out:
# {LinearRegression(): 56.34,
#  Lasso(): 56.34,
#  ElasticNet(): 46.28,
#  KNeighborsRegressor(): 55.13,
#  DecisionTreeRegressor(): 53.34,
#  RandomForestRegressor(): 82.97,
#  AdaBoostRegressor(): 56.2,
#  GradientBoostingRegressor(): 82.1}
